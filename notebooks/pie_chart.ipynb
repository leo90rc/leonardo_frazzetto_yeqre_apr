# %%
import matplotlib.pyplot as plt
import os, sys

# %%
project_path = os.path.dirname(os.getcwd())
sys.path.append(project_path)
sep = os.sep

# %%
from src.utils.folders_tb import excel_resources_df

# %%
horas_piechart = excel_resources_df('Horas_trabajo.xlsx')
horas_piechart.set_index('Tarea realizada', inplace= True)
plt.figure(figsize = (9,9))
plt.pie(horas_piechart.Horas,
       labels = horas_piechart.index,
       autopct='%1.2f%%')
plt.savefig('..' + sep + 'reports' + sep + 'piechart_tiempo.png');
