# %%
from PIL import Image
import os

# %%
sep = os.sep

# %%
foto_perro = Image.open('..' + sep + 'resources' + sep + 'perro_color.jpg')

# %%
foto_perro
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=880x495 at 0x1971A2EB988>

# %%
foto_perro_gray = foto_perro.convert(mode='L')

# %%
foto_perro_gray
# Out:
# <PIL.Image.Image image mode=L size=880x495 at 0x19719D47808>

# %%
foto_perro_gray.save('..' + sep + 'resources' + sep + 'perro_gray.jpg')
